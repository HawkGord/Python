# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = sorted(np.random.rand(10000))

# %%
def f(x):
    return np.multiply(np.sin(np.multiply(x,100)),x)+1

# %%
plt.plot(x, f(x))

# %%
S_par = 2
n = 1000000

# %%
# %%time
mont_carl = np.random.rand(n,2) # [x, y]
mont_carl = [[i[0],i[1]*2] for i in mont_carl]
res = [el for el in mont_carl if f(el[0]) > el[1]] # f(x) > y, то есть выбираем точки под графиком
S_fx = S_par*len(res)/n
print(S_fx)
# Out:
# 0.991974
# Wall time: 6.19 s

# %%
# %%time
import scipy.integrate as integrate
result = integrate.quad(lambda x: f(x), 0, 1)
result
# Out:
# Wall time: 1 ms
# (0.9913261747130123, 1.9950366599150293e-10)
